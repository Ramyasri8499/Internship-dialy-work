# %% [markdown]
# # Covariance & Correlation

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Ramya\OneDrive\Documents\study_marks.csv")
df
# Out:
#    Study_Hours  Marks
# 0          2.9   27.0
# 1          5.8   61.0
# 2          4.7   45.0
# 3          4.0   38.0
# 4          1.8   19.0
# 5          1.8    8.0
# 6          1.3    4.0
# 7          5.3   50.0
# 8          4.0   35.0
# 9          4.5   47.0

# %%
df.cov()
# Out:
#              Study_Hours       Marks
# Study_Hours     2.481000   28.906667
# Marks          28.906667  348.711111

# %%
df.corr()
# Out:
#              Study_Hours    Marks
# Study_Hours      1.00000  0.98277
# Marks            0.98277  1.00000

# %%
df=pd.read_csv(r"C:\Users\Ramya\OneDrive\Documents\temp_icecream_sales.csv")
df
# Out:
#    Temperature  IceCream_Sales
# 0           20             200
# 1           22             220
# 2           24             250
# 3           26             270
# 4           28             300
# 5           30             320
# 6           32             350
# 7           34             370
# 8           36             400
# 9           38             420

# %%
df.cov()
# Out:
#                 Temperature  IceCream_Sales
# Temperature       36.666667      455.555556
# IceCream_Sales   455.555556     5666.666667

# %%
df.corr()
# Out:
#                 Temperature  IceCream_Sales
# Temperature        1.000000        0.999406
# IceCream_Sales     0.999406        1.000000

# %%
df=pd.read_csv(r"C:\Users\Ramya\OneDrive\Documents\TEMP.csv")
df
# Out:
#    Temperature      Sunny
# 0           34         50
# 1           24         45
# 2           34         36
# 3           12         56
# 4           67         78
# 5           78         89
# 6           89         78

# %%
df.cov()
# Out:
#              Temperature       Sunny
# Temperature   867.571429  487.761905
#     Sunny     487.761905  397.571429

# %%
data={
    "temp":[-20,-30,-40,-60],
    "hum":[100,150,140,130]
}
df=pd.DataFrame(data)
df
# Out:
#    temp  hum
# 0   -20  100
# 1   -30  150
# 2   -40  140
# 3   -60  130

# %%
df.cov()
# Out:
#             temp         hum
# temp  291.666667 -133.333333
# hum  -133.333333  466.666667

# %% [markdown]
# # normalization

# %%
s=pd.Series([1000,2000,3000,4000])
s
# Out:
# 0    1000
# 1    2000
# 2    3000
# 3    4000
# dtype: int64

# %%
v=((1000-1000)/(4000-1000))
v
# Out:
# 0.0

# %%
v=((2000-1000)/(4000-1000))            #v=(x-min()/max()-min())
v
# Out:
# 0.3333333333333333

# %%
v=((3000-1000)/(4000-1000))
v
# Out:
# 0.6666666666666666

# %%
v=((4000-1000)/(4000-1000))
v
# Out:
# 1.0

# %%
s.min()
# Out:
# 1000

# %%
s.max()
# Out:
# 4000

# %%
sd=(s-s.min())/(s.max()-s.min())
sd
# Out:
# 0    0.000000
# 1    0.333333
# 2    0.666667
# 3    1.000000
# dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
import pandas as pd

# %%
sd=MinMaxScaler().fit_transform(s.values.reshape(-1,1))
sd
# Out:
# array([[0.        ],
#        [0.33333333],
#        [0.66666667],
#        [1.        ]])

# %%
data={
    "temp":[-20,-30,-40,-60],
    "hum":[100,150,140,130]
}
df=pd.DataFrame(data)
df
# Out:
#    temp  hum
# 0   -20  100
# 1   -30  150
# 2   -40  140
# 3   -60  130

# %%
norm_data=MinMaxScaler().fit_transform(df)    ####normalization
norm_data
# Out:
# array([[1.  , 0.  ],
#        [0.75, 1.  ],
#        [0.5 , 0.8 ],
#        [0.  , 0.6 ]])

# %%
norm_df=pd.DataFrame(norm_data,columns=df.columns)
norm_df
# Out:
#    temp  hum
# 0  1.00  0.0
# 1  0.75  1.0
# 2  0.50  0.8
# 3  0.00  0.6

# %% [markdown]
# # Standardization

# %%
s=pd.Series([1000,2000,3000,4000])
s
# Out:
# 0    1000
# 1    2000
# 2    3000
# 3    4000
# dtype: int64

# %%
s.mean()
# Out:
# 2500.0

# %%
s.std()
# Out:
# 1290.9944487358057

# %%
zscore=(s-s.mean())/s.std()
zscore
# Out:
# 0   -1.161895
# 1   -0.387298
# 2    0.387298
# 3    1.161895
# dtype: float64

# %%
zscore=StandardScaler().fit_transform(s.values.reshape(-1,1))
zscore
# Out:
# array([[-1.34164079],
#        [-0.4472136 ],
#        [ 0.4472136 ],
#        [ 1.34164079]])

# %%
zscore=(s-s.mean())/s.std(ddof=0)
zscore
# Out:
# 0   -1.341641
# 1   -0.447214
# 2    0.447214
# 3    1.341641
# dtype: float64

# %%
data={
    "temp":[-20,-30,-40,-60],
    "hum":[100,150,140,130]
}
df=pd.DataFrame(data)
df
# Out:
#    temp  hum
# 0   -20  100
# 1   -30  150
# 2   -40  140
# 3   -60  130

# %%
zscore=StandardScaler().fit_transform(df)
zscoredf=pd.DataFrame(zscore, columns=df.columns)

# %%
zscore
# Out:
# array([[ 1.18321596, -1.60356745],
#        [ 0.50709255,  1.06904497],
#        [-0.16903085,  0.53452248],
#        [-1.52127766,  0.        ]])

# %%
zscoredf
# Out:
#        temp       hum
# 0  1.183216 -1.603567
# 1  0.507093  1.069045
# 2 -0.169031  0.534522
# 3 -1.521278  0.000000
