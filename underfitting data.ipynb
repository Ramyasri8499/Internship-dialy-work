# %% [markdown]
# # underfitting data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv(r"C:\Users\Ramya\OneDrive\Documents\datasets\underfitting_dataset.csv")
df
# Out:
#     Study_Hours  Marks
# 0             1      1
# 1             1      3
# 2             1      2
# 3             2      1
# 4             2      4
# 5             2      3
# 6             3      2
# 7             3      5
# 8             3      4
# 9             4      2
# 10            4      6
# 11            4      5
# 12            5      3
# 13            5      7
# 14            5      6
# 15            6      4
# 16            6      8
# 17            6      7
# 18            7      5
# 19            7      9
# 20            7      8
# 21            8      6
# 22            8     10
# 23            8      9
# 24            9      7
# 25            9     11
# 26            9     10
# 27           10      8
# 28           10     12
# 29           10     11

# %%
X = df[["Study_Hours"]]
Y = df["Marks"]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4)
X_train
# Out:
#     Study_Hours
# 20            7
# 0             1
# 15            6
# 22            8
# 24            9
# 16            6
# 5             2
# 14            5
# 26            9
# 9             4
# 8             3
# 10            4
# 12            5
# 6             3
# 27           10
# 29           10
# 21            8
# 25            9

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_train_pred = model.predict(X_train)
Y_test_pred = model.predict(X_test)

# %%
Y_train_pred
# Out:
# array([7.03448276, 1.168357  , 6.05679513, 8.01217039, 8.98985801,
#        6.05679513, 2.14604462, 5.07910751, 8.98985801, 4.10141988,
#        3.12373225, 4.10141988, 5.07910751, 3.12373225, 9.96754564,
#        9.96754564, 8.01217039, 8.98985801])

# %%
Y_test_pred
# Out:
# array([7.03448276, 8.01217039, 7.03448276, 4.10141988, 6.05679513,
#        2.14604462, 1.168357  , 1.168357  , 5.07910751, 3.12373225,
#        9.96754564, 2.14604462])

# %%
train_mse = mean_squared_error(Y_train, Y_train_pred)
test_mse = mean_squared_error(Y_test, Y_test_pred)

# %%
print("Training MSE:", train_mse)
print("Testing MSE:", test_mse)
# Out:
# Training MSE: 2.604237097137706
# Testing MSE: 2.5677884569229534

# %%
plt.figure()
plt.scatter(X,Y)
plt.plot(X, model.predict(X))
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Linear Regression Model")
plt.show()

# %%
residuals = Y_test - Y_test_pred
residuals
# Out:
# 19    1.965517
# 23    0.987830
# 18   -2.034483
# 11    0.898580
# 17    0.943205
# 3    -1.146045
# 1     1.831643
# 2     0.831643
# 13    1.920892
# 7     1.876268
# 28    2.032454
# 4     1.853955
# Name: Marks, dtype: float64

# %%
plt.figure()
plt.scatter(X_test,residuals)
plt.axhline(0)
plt.xlabel("Study Hours (Test)")
plt.ylabel("Residuals")
plt.title("Residuals Plot (Test Data)")
plt.show()
